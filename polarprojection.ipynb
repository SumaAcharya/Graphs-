# %% [markdown]
# # Polar Projection Graph.

# %%
from numpy import pi,sin,cos,sqrt
import matplotlib.pyplot as plt
import numpy as np
plt.axes(projection='polar')

a=7
b=7
theta=np.arange(0,2*pi,pi/180)
for t in theta:
    r=(a*b)/sqrt((a*sin(t))**2+(b*cos(t))**2)
    plt.polar(t,r,'r')
plt.show()
